# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Preprocessing

# %%
import pandas as pd
import html
import re

# %%
mails = pd.read_csv('/content/drive/MyDrive/kluza/all_mails.csv', header=0)
keywords = pd.read_csv('/content/drive/MyDrive/kluza/keywords.csv', header=0)
metalabel = pd.read_csv('/content/drive/MyDrive/kluza/metalabel.csv', header=0)

# %%
def clear_text(text):
  cleared_text = html.unescape(text)
  cleared_text = cleared_text.split('\n>')[0]
  cleared_text = cleared_text.replace('\n', ' ')
  return cleared_text
mails['content'] = mails['content'].apply(clear_text)

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    cleaned_text = re.sub(r'[^\w\s]', '', text)

    cleaned_text = cleaned_text.lower()

    cleaned_text = re.sub(r'\bhttps\w+\b', '', cleaned_text)

    tokens = cleaned_text.split()
    filtered_tokens = [token for token in tokens if token not in stop_words]

    
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

    return ' '.join(lemmatized_tokens)

mails['content'] = mails['content'].apply(preprocess_text)

# %% [markdown]
# # Observation

# %%
mails['content'][100]
# Out:
# 'work camel11108 started luca burgazzoli'

# %%
mails['content'][101]
# Out:
# 'asf github bot commented camel11108 github user lburgazzoli opened pull request wip camel11108 camelinfinispan change uri syntax infinispanhostname infinispancachename tristantarrant may check missed something infinispan side merge pull request git repository running git pull camel11108 alternatively review apply change patch close pull request make commit mastertrunk branch least following commit message close 1604 commit 14fa5e5156e3e0e0e76cfdd23427a06febc27714 author lburgazzoli lburgazzoligmailcom date 20170406t131154z camel11108 camelinfinispan change uri syntax infinispanhostname infinispancachename'

# %%
mails['content_url'][101]
# Out:
# 'http://mail-archives.apache.org/mod_mbox/camel-issues/201704.mbox/ajax/%3CJIRA.13061654.1491378117000.225309.1491493301861%40Atlassian.JIRA%3E'

# %% [markdown]
# # Event log extraction

# %%
import spacy
from spacy.matcher import Matcher
import re
nlp = spacy.load('en_core_web_sm')
matcher = Matcher(nlp.vocab)

# %%
body_text = mails['content'][1]
noun_phrases = {}
verbs = {}
no_ph = []
ve = []

doc = nlp(body_text)

no_ph = [chunk.text for chunk in doc.noun_chunks]
ve = [token.lemma_ for token in doc if token.pos_ == "VERB"]
for i in range(len(ve)):
    if ve[i] in verbs:
        verbs[ve[i]] += 1
    else:
        verbs[ve[i]] = 1
ve = []

# %%
body_text = mails['content']
noun_phrases = {}
verbs = {}
no_ph = []
ve = []

for text in body_text:
    doc = nlp(text)

    no_ph = [chunk.text for chunk in doc.noun_chunks]
    ve = [token.lemma_ for token in doc if token.pos_ == "VERB"]
    for i in range(len(ve)):
      if(ve[i] in verbs):
        verbs[ve[i]] += 1
      else:
        verbs[ve[i]] = 1
    ve = []

# %%
sorted_verbs = dict(sorted(verbs.items(), key=lambda item: item[1], reverse=True))
sorted_verbs = {k: v for k, v in sorted_verbs.items() if v >= 31}

# %%
sorted_verbs
# Out:
# {'comment': 330,
#  'fix': 218,
#  'create': 206,
#  'send': 200,
#  'update': 200,
#  'resolve': 183,
#  'use': 177,
#  'commit': 134,
#  'make': 111,
#  'pull': 107,
#  'add': 102,
#  'close': 94,
#  'run': 91,
#  'take': 81,
#  'need': 80,
#  'get': 77,
#  'follow': 76,
#  'fail': 67,
#  'set': 64,
#  'allow': 61,
#  'affect': 59,
#  'open': 56,
#  'apply': 56,
#  'patch': 56,
#  'see': 52,
#  'find': 51,
#  'merge': 50,
#  'seem': 50,
#  'reassign': 49,
#  'provide': 49,
#  'work': 45,
#  'think': 44,
#  'generate': 37,
#  'try': 36,
#  'warn': 36,
#  'implement': 32,
#  'start': 31,
#  'request': 31,
#  'do': 31}

# %%
event_patterns = [[{"LOWER": key}] for key in sorted_verbs.keys()]

# %%
event_patterns
# Out:
# [[{'LOWER': 'comment'}],
#  [{'LOWER': 'fix'}],
#  [{'LOWER': 'create'}],
#  [{'LOWER': 'send'}],
#  [{'LOWER': 'update'}],
#  [{'LOWER': 'resolve'}],
#  [{'LOWER': 'use'}],
#  [{'LOWER': 'commit'}],
#  [{'LOWER': 'make'}],
#  [{'LOWER': 'pull'}],
#  [{'LOWER': 'add'}],
#  [{'LOWER': 'close'}],
#  [{'LOWER': 'run'}],
#  [{'LOWER': 'take'}],
#  [{'LOWER': 'need'}],
#  [{'LOWER': 'get'}],
#  [{'LOWER': 'follow'}],
#  [{'LOWER': 'fail'}],
#  [{'LOWER': 'set'}],
#  [{'LOWER': 'allow'}],
#  [{'LOWER': 'affect'}],
#  [{'LOWER': 'open'}],
#  [{'LOWER': 'apply'}],
#  [{'LOWER': 'patch'}],
#  [{'LOWER': 'see'}],
#  [{'LOWER': 'find'}],
#  [{'LOWER': 'merge'}],
#  [{'LOWER': 'seem'}],
#  [{'LOWER': 'reassign'}],
#  [{'LOWER': 'provide'}],
#  [{'LOWER': 'work'}],
#  [{'LOWER': 'think'}],
#  [{'LOWER': 'generate'}],
#  [{'LOWER': 'try'}],
#  [{'LOWER': 'warn'}],
#  [{'LOWER': 'implement'}],
#  [{'LOWER': 'start'}],
#  [{'LOWER': 'request'}],
#  [{'LOWER': 'do'}]]

# %%
def extract_event(doc):
    for pattern in event_patterns:
        matcher.add("Event", [pattern])
    matches = matcher(doc)

    events = []
    for match_id, start, end in matches:
        events.append(doc[start:end].text)

    return events if events else None

def extract_object(doc, event):
    context_window = 2

    for i, token in enumerate(doc):
        if token.lower_ == event:
            start_index = max(0, i - context_window)
            end_index = min(len(doc), i + context_window + 1)

            for j in range(start_index, end_index):
                if doc[j].pos_ == 'NOUN':
                    return doc[j].text

    return None



def extract_actor(doc):
    actors = []
    for entity in doc.ents:
        if entity.label_ == "PERSON":
            actors.append(entity.text)

    if actors:
        return actors[0]

    return None

# %%
ocel_entries = []

for i in range(len(mails['content'])):
    doc = nlp(mails['content'][i])
    events = extract_event(doc)

    if events:
        for event in events:
            event_entry = {}
            event_entry['Id'] = i
            event_entry['Event'] = event
            event_entry['Object'] = extract_object(doc, event)
            event_entry['Actor'] = extract_actor(doc)
            event_entry['Timestamp'] = mails['date'][i]

            ocel_entries.append(event_entry)

# %%
ocel_entries
# Out:
# [{'Id': 0,
#   'Event': 'create',
#   'Object': 'create',
#   'Actor': 'daniel fullarton',
#   'Timestamp': 'Sun, 02 Apr, 23:59'},
#  {'Id': 1,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'resolve',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'merge',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'apply',
#   'Object': 'review',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'patch',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'make',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 1,
#   'Event': 'resolve',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 00:01'},
#  {'Id': 2,
#   'Event': 'fix',
#   'Object': 'fix',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Tue, 04 Apr, 13:33'},
#  {'Id': 3,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 01:38'},
#  {'Id': 3,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 01:38'},
#  {'Id': 4,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': nan},
#  {'Id': 4,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': nan},
#  {'Id': 5,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 07:44'},
#  {'Id': 5,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 07:44'},
#  {'Id': 7,
#   'Event': 'fix',
#   'Object': 'resolution',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Wed, 12 Apr, 08:46'},
#  {'Id': 8,
#   'Event': 'fix',
#   'Object': 'resolution',
#   'Actor': 'zoran regvart',
#   'Timestamp': nan},
#  {'Id': 10,
#   'Event': 'fix',
#   'Object': 'resolution',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Mon, 03 Apr, 08:05'},
#  {'Id': 11,
#   'Event': 'pull',
#   'Object': 'onders86',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 08:14'},
#  {'Id': 11,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 08:14'},
#  {'Id': 12,
#   'Event': 'pull',
#   'Object': 'onders86',
#   'Actor': 'asf github',
#   'Timestamp': nan},
#  {'Id': 12,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': nan},
#  {'Id': 13,
#   'Event': 'add',
#   'Object': 'summary',
#   'Actor': 'camel11100',
#   'Timestamp': 'Mon, 03 Apr, 09:48'},
#  {'Id': 13,
#   'Event': 'use',
#   'Object': 'configure',
#   'Actor': 'camel11100',
#   'Timestamp': 'Mon, 03 Apr, 09:48'},
#  {'Id': 13,
#   'Event': 'fix',
#   'Object': 'priority',
#   'Actor': 'camel11100',
#   'Timestamp': 'Mon, 03 Apr, 09:48'},
#  {'Id': 14,
#   'Event': 'work',
#   'Object': 'work',
#   'Actor': 'camel11100',
#   'Timestamp': 'Mon, 03 Apr, 09:56'},
#  {'Id': 17,
#   'Event': 'update',
#   'Object': 'summary',
#   'Actor': 'atlassian jira',
#   'Timestamp': 'Mon, 03 Apr, 11:37'},
#  {'Id': 17,
#   'Event': 'affect',
#   'Object': 'component',
#   'Actor': 'atlassian jira',
#   'Timestamp': 'Mon, 03 Apr, 11:37'},
#  {'Id': 17,
#   'Event': 'update',
#   'Object': 'summary',
#   'Actor': 'atlassian jira',
#   'Timestamp': 'Mon, 03 Apr, 11:37'},
#  {'Id': 17,
#   'Event': 'fix',
#   'Object': 'version',
#   'Actor': 'atlassian jira',
#   'Timestamp': 'Mon, 03 Apr, 11:37'},
#  {'Id': 17,
#   'Event': 'fix',
#   'Object': 'version',
#   'Actor': 'atlassian jira',
#   'Timestamp': 'Mon, 03 Apr, 11:37'},
#  {'Id': 18,
#   'Event': 'fix',
#   'Object': 'resolution',
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Tue, 04 Apr, 12:37'},
#  {'Id': 19,
#   'Event': 'fix',
#   'Object': 'resolution',
#   'Actor': 'claus ibsen',
#   'Timestamp': nan},
#  {'Id': 22,
#   'Event': 'pull',
#   'Object': 'onders86',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'get',
#   'Object': 'websocket',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'set',
#   'Object': 'merge',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'merge',
#   'Object': 'merge',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'pull',
#   'Object': 'onders86',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'pull',
#   'Object': 'onders86',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'apply',
#   'Object': 'review',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'patch',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'pull',
#   'Object': 'onders86',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'make',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'get',
#   'Object': 'websocket',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 22,
#   'Event': 'set',
#   'Object': 'merge',
#   'Actor': 'asf github',
#   'Timestamp': 'Mon, 03 Apr, 13:52'},
#  {'Id': 23,
#   'Event': 'fix',
#   'Object': 'resolution',
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Tue, 04 Apr, 14:38'},
#  {'Id': 24,
#   'Event': 'pull',
#   'Object': 'onders86',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 15:42'},
#  {'Id': 24,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 15:42'},
#  {'Id': 25,
#   'Event': 'pull',
#   'Object': 'onders86',
#   'Actor': 'asf github',
#   'Timestamp': nan},
#  {'Id': 25,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': nan},
#  {'Id': 26,
#   'Event': 'affect',
#   'Object': 'component',
#   'Actor': 'ayush dixit',
#   'Timestamp': 'Tue, 04 Apr, 06:53'},
#  {'Id': 26,
#   'Event': 'set',
#   'Object': 'producer',
#   'Actor': 'ayush dixit',
#   'Timestamp': 'Tue, 04 Apr, 06:53'},
#  {'Id': 28,
#   'Event': 'use',
#   'Object': 'camel',
#   'Actor': 'andrea cosentino',
#   'Timestamp': 'Tue, 04 Apr, 06:56'},
#  {'Id': 29,
#   'Event': 'set',
#   'Object': 'producer',
#   'Actor': 'ayush dixit',
#   'Timestamp': 'Tue, 04 Apr, 06:58'},
#  {'Id': 30,
#   'Event': 'set',
#   'Object': 'producer',
#   'Actor': 'ayush dixit',
#   'Timestamp': 'Tue, 04 Apr, 06:59'},
#  {'Id': 31,
#   'Event': 'set',
#   'Object': 'producer',
#   'Actor': 'ayush dixit',
#   'Timestamp': 'Tue, 04 Apr, 06:59'},
#  {'Id': 31,
#   'Event': 'set',
#   'Object': 'producer',
#   'Actor': 'ayush dixit',
#   'Timestamp': 'Tue, 04 Apr, 06:59'},
#  {'Id': 32,
#   'Event': 'set',
#   'Object': 'producer',
#   'Actor': 'ayush dixit',
#   'Timestamp': 'Tue, 04 Apr, 07:00'},
#  {'Id': 32,
#   'Event': 'set',
#   'Object': 'producer',
#   'Actor': 'ayush dixit',
#   'Timestamp': 'Tue, 04 Apr, 07:00'},
#  {'Id': 33,
#   'Event': 'set',
#   'Object': 'producer',
#   'Actor': 'ayush dixit',
#   'Timestamp': nan},
#  {'Id': 33,
#   'Event': 'set',
#   'Object': 'producer',
#   'Actor': 'ayush dixit',
#   'Timestamp': nan},
#  {'Id': 34,
#   'Event': 'add',
#   'Object': 'camel11103',
#   'Actor': 'andrea cosentino',
#   'Timestamp': 'Tue, 04 Apr, 07:11'},
#  {'Id': 35,
#   'Event': 'add',
#   'Object': 'camel11103',
#   'Actor': 'andrea cosentino',
#   'Timestamp': nan},
#  {'Id': 38,
#   'Event': 'affect',
#   'Object': 'component',
#   'Actor': 'ayush dixit',
#   'Timestamp': 'Tue, 04 Apr, 07:32'},
#  {'Id': 38,
#   'Event': 'find',
#   'Object': 'location',
#   'Actor': 'ayush dixit',
#   'Timestamp': 'Tue, 04 Apr, 07:32'},
#  {'Id': 38,
#   'Event': 'set',
#   'Object': 'producer',
#   'Actor': 'ayush dixit',
#   'Timestamp': 'Tue, 04 Apr, 07:32'},
#  {'Id': 39,
#   'Event': 'use',
#   'Object': 'resolution',
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Tue, 04 Apr, 07:36'},
#  {'Id': 41,
#   'Event': 'do',
#   'Object': None,
#   'Actor': 'andrea cosentino',
#   'Timestamp': 'Tue, 04 Apr, 07:49'},
#  {'Id': 41,
#   'Event': 'open',
#   'Object': 'issue',
#   'Actor': 'andrea cosentino',
#   'Timestamp': 'Tue, 04 Apr, 07:49'},
#  {'Id': 42,
#   'Event': 'do',
#   'Object': None,
#   'Actor': 'andrea cosentino',
#   'Timestamp': nan},
#  {'Id': 42,
#   'Event': 'open',
#   'Object': 'issue',
#   'Actor': 'andrea cosentino',
#   'Timestamp': nan},
#  {'Id': 46,
#   'Event': 'see',
#   'Object': 'documentsas',
#   'Actor': None,
#   'Timestamp': 'Tue, 04 Apr, 08:25'},
#  {'Id': 46,
#   'Event': 'use',
#   'Object': 'port',
#   'Actor': None,
#   'Timestamp': 'Tue, 04 Apr, 08:25'},
#  {'Id': 48,
#   'Event': 'work',
#   'Object': 'port',
#   'Actor': None,
#   'Timestamp': 'Mon, 10 Apr, 15:50'},
#  {'Id': 48,
#   'Event': 'request',
#   'Object': 'discover',
#   'Actor': None,
#   'Timestamp': 'Mon, 10 Apr, 15:50'},
#  {'Id': 48,
#   'Event': 'make',
#   'Object': 'sense',
#   'Actor': None,
#   'Timestamp': 'Mon, 10 Apr, 15:50'},
#  {'Id': 49,
#   'Event': 'see',
#   'Object': 'see',
#   'Actor': None,
#   'Timestamp': 'Tue, 18 Apr, 07:44'},
#  {'Id': 49,
#   'Event': 'provide',
#   'Object': 'code',
#   'Actor': None,
#   'Timestamp': 'Tue, 18 Apr, 07:44'},
#  {'Id': 49,
#   'Event': 'provide',
#   'Object': 'code',
#   'Actor': None,
#   'Timestamp': 'Tue, 18 Apr, 07:44'},
#  {'Id': 49,
#   'Event': 'do',
#   'Object': 'documentation',
#   'Actor': None,
#   'Timestamp': 'Tue, 18 Apr, 07:44'},
#  {'Id': 49,
#   'Event': 'add',
#   'Object': 'statement',
#   'Actor': None,
#   'Timestamp': 'Tue, 18 Apr, 07:44'},
#  {'Id': 49,
#   'Event': 'close',
#   'Object': 'statement',
#   'Actor': None,
#   'Timestamp': 'Tue, 18 Apr, 07:44'},
#  {'Id': 49,
#   'Event': 'do',
#   'Object': 'documentation',
#   'Actor': None,
#   'Timestamp': 'Tue, 18 Apr, 07:44'},
#  {'Id': 49,
#   'Event': 'create',
#   'Object': None,
#   'Actor': None,
#   'Timestamp': 'Tue, 18 Apr, 07:44'},
#  {'Id': 49,
#   'Event': 'see',
#   'Object': 'see',
#   'Actor': None,
#   'Timestamp': 'Tue, 18 Apr, 07:44'},
#  {'Id': 52,
#   'Event': 'allow',
#   'Object': 'summary',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:00'},
#  {'Id': 52,
#   'Event': 'send',
#   'Object': 'osgi',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:00'},
#  {'Id': 52,
#   'Event': 'use',
#   'Object': 'task',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:00'},
#  {'Id': 52,
#   'Event': 'try',
#   'Object': 'event',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:00'},
#  {'Id': 52,
#   'Event': 'get',
#   'Object': 'event',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:00'},
#  {'Id': 52,
#   'Event': 'start',
#   'Object': 'orgapachecamelfailedtostartrouteexception',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:00'},
#  {'Id': 52,
#   'Event': 'think',
#   'Object': 'endpointeventadminmycustomevents',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:00'},
#  {'Id': 53,
#   'Event': 'send',
#   'Object': 'osgi',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:01'},
#  {'Id': 53,
#   'Event': 'try',
#   'Object': 'event',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:01'},
#  {'Id': 53,
#   'Event': 'get',
#   'Object': 'event',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:01'},
#  {'Id': 53,
#   'Event': 'start',
#   'Object': 'orgapachecamelfailedtostartrouteexception',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:01'},
#  {'Id': 53,
#   'Event': 'think',
#   'Object': 'endpointeventadminmycustomevents',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:01'},
#  {'Id': 53,
#   'Event': 'send',
#   'Object': 'osgi',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:01'},
#  {'Id': 53,
#   'Event': 'use',
#   'Object': 'task',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:01'},
#  {'Id': 53,
#   'Event': 'try',
#   'Object': 'event',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:01'},
#  {'Id': 53,
#   'Event': 'get',
#   'Object': 'event',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:01'},
#  {'Id': 53,
#   'Event': 'start',
#   'Object': 'orgapachecamelfailedtostartrouteexception',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:01'},
#  {'Id': 53,
#   'Event': 'think',
#   'Object': 'endpointeventadminmycustomevents',
#   'Actor': 'david franke',
#   'Timestamp': 'Tue, 04 Apr, 09:01'},
#  {'Id': 57,
#   'Event': 'need',
#   'Object': 'endpoint',
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Tue, 04 Apr, 12:40'},
#  {'Id': 58,
#   'Event': 'pull',
#   'Object': 'onders86',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 06:32'},
#  {'Id': 58,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 06:32'},
#  {'Id': 58,
#   'Event': 'merge',
#   'Object': 'endpoint',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 06:32'},
#  {'Id': 58,
#   'Event': 'pull',
#   'Object': 'onders86',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 06:32'},
#  {'Id': 58,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 06:32'},
#  {'Id': 58,
#   'Event': 'pull',
#   'Object': 'onders86',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 06:32'},
#  {'Id': 58,
#   'Event': 'apply',
#   'Object': 'review',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 06:32'},
#  {'Id': 58,
#   'Event': 'patch',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 06:32'},
#  {'Id': 58,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 06:32'},
#  {'Id': 58,
#   'Event': 'pull',
#   'Object': 'onders86',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 06:32'},
#  {'Id': 58,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 06:32'},
#  {'Id': 58,
#   'Event': 'make',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 06:32'},
#  {'Id': 58,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 06:32'},
#  {'Id': 58,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 06:32'},
#  {'Id': 58,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 06:32'},
#  {'Id': 58,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 06:32'},
#  {'Id': 59,
#   'Event': 'fix',
#   'Object': None,
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Thu, 06 Apr, 07:39'},
#  {'Id': 60,
#   'Event': 'pull',
#   'Object': 'onders86',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 08:26'},
#  {'Id': 60,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 08:26'},
#  {'Id': 61,
#   'Event': 'pull',
#   'Object': 'onders86',
#   'Actor': 'asf github',
#   'Timestamp': nan},
#  {'Id': 61,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': nan},
#  {'Id': 62,
#   'Event': 'work',
#   'Object': 'work',
#   'Actor': None,
#   'Timestamp': 'Tue, 04 Apr, 11:23'},
#  {'Id': 65,
#   'Event': 'allow',
#   'Object': 'summary',
#   'Actor': 'camel11106',
#   'Timestamp': 'Tue, 04 Apr, 12:47'},
#  {'Id': 65,
#   'Event': 'create',
#   'Object': 'user',
#   'Actor': 'camel11106',
#   'Timestamp': 'Tue, 04 Apr, 12:47'},
#  {'Id': 65,
#   'Event': 'use',
#   'Object': None,
#   'Actor': 'camel11106',
#   'Timestamp': 'Tue, 04 Apr, 12:47'},
#  {'Id': 65,
#   'Event': 'try',
#   'Object': 'syntax',
#   'Actor': 'camel11106',
#   'Timestamp': 'Tue, 04 Apr, 12:47'},
#  {'Id': 65,
#   'Event': 'find',
#   'Object': 'spring',
#   'Actor': 'camel11106',
#   'Timestamp': 'Tue, 04 Apr, 12:47'},
#  {'Id': 65,
#   'Event': 'allow',
#   'Object': 'summary',
#   'Actor': 'camel11106',
#   'Timestamp': 'Tue, 04 Apr, 12:47'},
#  {'Id': 67,
#   'Event': 'affect',
#   'Object': 'version',
#   'Actor': 'camel11106',
#   'Timestamp': 'Tue, 04 Apr, 13:01'},
#  {'Id': 68,
#   'Event': 'fix',
#   'Object': 'fix',
#   'Actor': 'camel11106',
#   'Timestamp': 'Tue, 04 Apr, 13:01'},
#  {'Id': 71,
#   'Event': 'think',
#   'Object': 'camel11060',
#   'Actor': None,
#   'Timestamp': 'Tue, 04 Apr, 15:05'},
#  {'Id': 71,
#   'Event': 'set',
#   'Object': 'none',
#   'Actor': None,
#   'Timestamp': 'Tue, 04 Apr, 15:05'},
#  {'Id': 71,
#   'Event': 'see',
#   'Object': 'way',
#   'Actor': None,
#   'Timestamp': 'Tue, 04 Apr, 15:05'},
#  {'Id': 71,
#   'Event': 'set',
#   'Object': 'none',
#   'Actor': None,
#   'Timestamp': 'Tue, 04 Apr, 15:05'},
#  {'Id': 71,
#   'Event': 'work',
#   'Object': None,
#   'Actor': None,
#   'Timestamp': 'Tue, 04 Apr, 15:05'},
#  {'Id': 71,
#   'Event': 'think',
#   'Object': 'camel11060',
#   'Actor': None,
#   'Timestamp': 'Tue, 04 Apr, 15:05'},
#  {'Id': 72,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'patch',
#   'Object': 'base',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'make',
#   'Object': 'dn',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'merge',
#   'Object': 'place',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'apply',
#   'Object': 'review',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'patch',
#   'Object': 'base',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'make',
#   'Object': 'dn',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 72,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 18:41'},
#  {'Id': 73,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'ken geis',
#   'Timestamp': 'Tue, 04 Apr, 18:42'},
#  {'Id': 73,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'ken geis',
#   'Timestamp': 'Tue, 04 Apr, 18:42'},
#  {'Id': 74,
#   'Event': 'comment',
#   'Object': 'camel11060',
#   'Actor': 'ken geis',
#   'Timestamp': 'Tue, 04 Apr, 18:43'},
#  {'Id': 74,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'ken geis',
#   'Timestamp': 'Tue, 04 Apr, 18:43'},
#  {'Id': 74,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'ken geis',
#   'Timestamp': 'Tue, 04 Apr, 18:43'},
#  {'Id': 75,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 12 Apr, 08:30'},
#  {'Id': 75,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 12 Apr, 08:30'},
#  {'Id': 76,
#   'Event': 'fix',
#   'Object': None,
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Wed, 12 Apr, 08:30'},
#  {'Id': 77,
#   'Event': 'fix',
#   'Object': None,
#   'Actor': 'claus ibsen',
#   'Timestamp': nan},
#  {'Id': 78,
#   'Event': 'create',
#   'Object': 'camel11107',
#   'Actor': 'dmitry volodin',
#   'Timestamp': 'Tue, 04 Apr, 16:00'},
#  {'Id': 78,
#   'Event': 'affect',
#   'Object': 'type',
#   'Actor': 'dmitry volodin',
#   'Timestamp': 'Tue, 04 Apr, 16:00'},
#  {'Id': 78,
#   'Event': 'create',
#   'Object': 'camel11107',
#   'Actor': 'dmitry volodin',
#   'Timestamp': 'Tue, 04 Apr, 16:00'},
#  {'Id': 79,
#   'Event': 'create',
#   'Object': 'camel11107',
#   'Actor': 'dmitry volodin',
#   'Timestamp': 'Tue, 04 Apr, 16:03'},
#  {'Id': 79,
#   'Event': 'create',
#   'Object': 'camel11107',
#   'Actor': 'dmitry volodin',
#   'Timestamp': 'Tue, 04 Apr, 16:03'},
#  {'Id': 80,
#   'Event': 'pull',
#   'Object': 'dmvolod',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'create',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'create',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'merge',
#   'Object': 'async',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'pull',
#   'Object': 'dmvolod',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'pull',
#   'Object': 'dmvolod',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'apply',
#   'Object': 'review',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'patch',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'pull',
#   'Object': 'dmvolod',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'make',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'create',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 80,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 09:41'},
#  {'Id': 83,
#   'Event': 'fix',
#   'Object': 'fix',
#   'Actor': 'andrea cosentino',
#   'Timestamp': 'Wed, 05 Apr, 13:33'},
#  {'Id': 85,
#   'Event': 'pull',
#   'Object': 'dmvolod',
#   'Actor': 'asf github',
#   'Timestamp': 'Fri, 07 Apr, 12:31'},
#  {'Id': 85,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Fri, 07 Apr, 12:31'},
#  {'Id': 86,
#   'Event': 'pull',
#   'Object': 'dmvolod',
#   'Actor': 'asf github',
#   'Timestamp': nan},
#  {'Id': 86,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': nan},
#  {'Id': 88,
#   'Event': 'take',
#   'Object': 'annotation',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Tue, 04 Apr, 17:52'},
#  {'Id': 88,
#   'Event': 'get',
#   'Object': 'work',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Tue, 04 Apr, 17:52'},
#  {'Id': 88,
#   'Event': 'work',
#   'Object': 'work',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Tue, 04 Apr, 17:52'},
#  {'Id': 88,
#   'Event': 'create',
#   'Object': None,
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Tue, 04 Apr, 17:52'},
#  {'Id': 89,
#   'Event': 'fix',
#   'Object': 'resolution',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Thu, 13 Apr, 11:08'},
#  {'Id': 90,
#   'Event': 'fix',
#   'Object': 'resolution',
#   'Actor': 'zoran regvart',
#   'Timestamp': nan},
#  {'Id': 92,
#   'Event': 'do',
#   'Object': 'route',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Tue, 04 Apr, 17:51'},
#  {'Id': 92,
#   'Event': 'think',
#   'Object': 'field',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Tue, 04 Apr, 17:51'},
#  {'Id': 92,
#   'Event': 'make',
#   'Object': 'method',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Tue, 04 Apr, 17:51'},
#  {'Id': 92,
#   'Event': 'create',
#   'Object': 'annotation',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Tue, 04 Apr, 17:51'},
#  {'Id': 93,
#   'Event': 'take',
#   'Object': 'take',
#   'Actor': 'posta twitter',
#   'Timestamp': 'Tue, 04 Apr, 17:55'},
#  {'Id': 93,
#   'Event': 'send',
#   'Object': 'take',
#   'Actor': 'posta twitter',
#   'Timestamp': 'Tue, 04 Apr, 17:55'},
#  {'Id': 94,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'create',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'need',
#   'Object': 'need',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'generate',
#   'Object': 'annotation',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'generate',
#   'Object': 'annotation',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'generate',
#   'Object': 'annotation',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'fail',
#   'Object': 'resource',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'try',
#   'Object': 'location',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'use',
#   'Object': 'destinationgenerator',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'merge',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'apply',
#   'Object': 'review',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'patch',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'make',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'create',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'generate',
#   'Object': 'annotation',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'generate',
#   'Object': 'annotation',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'generate',
#   'Object': 'annotation',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'fail',
#   'Object': 'resource',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'try',
#   'Object': 'location',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 94,
#   'Event': 'use',
#   'Object': 'destinationgenerator',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 04 Apr, 21:16'},
#  {'Id': 95,
#   'Event': 'fix',
#   'Object': None,
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Thu, 13 Apr, 07:58'},
#  {'Id': 95,
#   'Event': 'close',
#   'Object': 'traction',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Thu, 13 Apr, 07:58'},
#  {'Id': 96,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 07:58'},
#  {'Id': 96,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 07:58'},
#  {'Id': 97,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': nan},
#  {'Id': 97,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': nan},
#  {'Id': 98,
#   'Event': 'fix',
#   'Object': 'priority',
#   'Actor': 'camel11108',
#   'Timestamp': 'Wed, 05 Apr, 07:42'},
#  {'Id': 98,
#   'Event': 'use',
#   'Object': 'case',
#   'Actor': 'camel11108',
#   'Timestamp': 'Wed, 05 Apr, 07:42'},
#  {'Id': 98,
#   'Event': 'set',
#   'Object': 'host',
#   'Actor': 'camel11108',
#   'Timestamp': 'Wed, 05 Apr, 07:42'},
#  {'Id': 98,
#   'Event': 'make',
#   'Object': 'change',
#   'Actor': 'camel11108',
#   'Timestamp': 'Wed, 05 Apr, 07:42'},
#  {'Id': 98,
#   'Event': 'make',
#   'Object': 'change',
#   'Actor': 'camel11108',
#   'Timestamp': 'Wed, 05 Apr, 07:42'},
#  {'Id': 98,
#   'Event': 'use',
#   'Object': 'case',
#   'Actor': 'camel11108',
#   'Timestamp': 'Wed, 05 Apr, 07:42'},
#  {'Id': 100,
#   'Event': 'work',
#   'Object': 'work',
#   'Actor': 'camel11108',
#   'Timestamp': 'Thu, 06 Apr, 11:54'},
#  {'Id': 101,
#   'Event': 'pull',
#   'Object': 'lburgazzoli',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 15:41'},
#  {'Id': 101,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 15:41'},
#  {'Id': 101,
#   'Event': 'merge',
#   'Object': 'infinispan',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 15:41'},
#  {'Id': 101,
#   'Event': 'pull',
#   'Object': 'lburgazzoli',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 15:41'},
#  {'Id': 101,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 15:41'},
#  {'Id': 101,
#   'Event': 'pull',
#   'Object': 'lburgazzoli',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 15:41'},
#  {'Id': 101,
#   'Event': 'apply',
#   'Object': 'review',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 15:41'},
#  {'Id': 101,
#   'Event': 'patch',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 15:41'},
#  {'Id': 101,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 15:41'},
#  {'Id': 101,
#   'Event': 'pull',
#   'Object': 'lburgazzoli',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 15:41'},
#  {'Id': 101,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 15:41'},
#  {'Id': 101,
#   'Event': 'make',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 15:41'},
#  {'Id': 101,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 15:41'},
#  {'Id': 101,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 15:41'},
#  {'Id': 101,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 15:41'},
#  {'Id': 101,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 06 Apr, 15:41'},
#  {'Id': 102,
#   'Event': 'pull',
#   'Object': 'lburgazzoli',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 12 Apr, 07:45'},
#  {'Id': 102,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 12 Apr, 07:45'},
#  {'Id': 105,
#   'Event': 'resolve',
#   'Object': 'summary',
#   'Actor': 'routeroute1fromjmsqueuequeue1destinationconsumerex',
#   'Timestamp': 'Wed, 05 Apr, 08:32'},
#  {'Id': 105,
#   'Event': 'affect',
#   'Object': 'component',
#   'Actor': 'routeroute1fromjmsqueuequeue1destinationconsumerex',
#   'Timestamp': 'Wed, 05 Apr, 08:32'},
#  {'Id': 105,
#   'Event': 'fix',
#   'Object': 'schneider',
#   'Actor': 'routeroute1fromjmsqueuequeue1destinationconsumerex',
#   'Timestamp': 'Wed, 05 Apr, 08:32'},
#  {'Id': 105,
#   'Event': 'fail',
#   'Object': 'queue',
#   'Actor': 'routeroute1fromjmsqueuequeue1destinationconsumerex',
#   'Timestamp': 'Wed, 05 Apr, 08:32'},
#  {'Id': 105,
#   'Event': 'resolve',
#   'Object': 'summary',
#   'Actor': 'routeroute1fromjmsqueuequeue1destinationconsumerex',
#   'Timestamp': 'Wed, 05 Apr, 08:32'},
#  {'Id': 105,
#   'Event': 'create',
#   'Object': 'orgapachecamelfailedtocreaterouteexception',
#   'Actor': 'routeroute1fromjmsqueuequeue1destinationconsumerex',
#   'Timestamp': 'Wed, 05 Apr, 08:32'},
#  {'Id': 105,
#   'Event': 'resolve',
#   'Object': 'summary',
#   'Actor': 'routeroute1fromjmsqueuequeue1destinationconsumerex',
#   'Timestamp': 'Wed, 05 Apr, 08:32'},
#  {'Id': 105,
#   'Event': 'resolve',
#   'Object': 'summary',
#   'Actor': 'routeroute1fromjmsqueuequeue1destinationconsumerex',
#   'Timestamp': 'Wed, 05 Apr, 08:32'},
#  {'Id': 105,
#   'Event': 'set',
#   'Object': 'endpoint',
#   'Actor': 'routeroute1fromjmsqueuequeue1destinationconsumerex',
#   'Timestamp': 'Wed, 05 Apr, 08:32'},
#  {'Id': 105,
#   'Event': 'resolve',
#   'Object': 'summary',
#   'Actor': 'routeroute1fromjmsqueuequeue1destinationconsumerex',
#   'Timestamp': 'Wed, 05 Apr, 08:32'},
#  {'Id': 105,
#   'Event': 'resolve',
#   'Object': 'summary',
#   'Actor': 'routeroute1fromjmsqueuequeue1destinationconsumerex',
#   'Timestamp': 'Wed, 05 Apr, 08:32'},
#  {'Id': 105,
#   'Event': 'set',
#   'Object': 'endpoint',
#   'Actor': 'routeroute1fromjmsqueuequeue1destinationconsumerex',
#   'Timestamp': 'Wed, 05 Apr, 08:32'},
#  {'Id': 105,
#   'Event': 'resolve',
#   'Object': 'summary',
#   'Actor': 'routeroute1fromjmsqueuequeue1destinationconsumerex',
#   'Timestamp': 'Wed, 05 Apr, 08:32'},
#  {'Id': 105,
#   'Event': 'set',
#   'Object': 'endpoint',
#   'Actor': 'routeroute1fromjmsqueuequeue1destinationconsumerex',
#   'Timestamp': 'Wed, 05 Apr, 08:32'},
#  {'Id': 106,
#   'Event': 'fix',
#   'Object': 'version',
#   'Actor': None,
#   'Timestamp': 'Wed, 05 Apr, 12:04'},
#  {'Id': 106,
#   'Event': 'fix',
#   'Object': 'version',
#   'Actor': None,
#   'Timestamp': 'Wed, 05 Apr, 12:04'},
#  {'Id': 106,
#   'Event': 'close',
#   'Object': 'claus',
#   'Actor': None,
#   'Timestamp': 'Wed, 05 Apr, 12:04'},
#  {'Id': 107,
#   'Event': 'fix',
#   'Object': 'version',
#   'Actor': None,
#   'Timestamp': nan},
#  {'Id': 107,
#   'Event': 'fix',
#   'Object': 'version',
#   'Actor': None,
#   'Timestamp': nan},
#  {'Id': 107,
#   'Event': 'close',
#   'Object': 'claus',
#   'Actor': None,
#   'Timestamp': nan},
#  {'Id': 108,
#   'Event': 'affect',
#   'Object': 'component',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Wed, 05 Apr, 09:33'},
#  {'Id': 108,
#   'Event': 'try',
#   'Object': 'rest',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Wed, 05 Apr, 09:33'},
#  {'Id': 108,
#   'Event': 'resolve',
#   'Object': 'component',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Wed, 05 Apr, 09:33'},
#  {'Id': 108,
#   'Event': 'set',
#   'Object': 'value',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Wed, 05 Apr, 09:33'},
#  {'Id': 108,
#   'Event': 'try',
#   'Object': 'rest',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Wed, 05 Apr, 09:33'},
#  {'Id': 108,
#   'Event': 'resolve',
#   'Object': 'component',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Wed, 05 Apr, 09:33'},
#  {'Id': 109,
#   'Event': 'fix',
#   'Object': 'resolution',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Wed, 05 Apr, 09:38'},
#  {'Id': 109,
#   'Event': 'fix',
#   'Object': 'resolution',
#   'Actor': 'zoran regvart',
#   'Timestamp': 'Wed, 05 Apr, 09:38'},
#  {'Id': 110,
#   'Event': 'fix',
#   'Object': 'resolution',
#   'Actor': 'zoran regvart',
#   'Timestamp': nan},
#  {'Id': 110,
#   'Event': 'fix',
#   'Object': 'resolution',
#   'Actor': 'zoran regvart',
#   'Timestamp': nan},
#  {'Id': 111,
#   'Event': 'work',
#   'Object': None,
#   'Actor': 'scott cranton',
#   'Timestamp': 'Wed, 05 Apr, 11:10'},
#  {'Id': 111,
#   'Event': 'affect',
#   'Object': 'component',
#   'Actor': 'scott cranton',
#   'Timestamp': 'Wed, 05 Apr, 11:10'},
#  {'Id': 112,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:49'},
#  {'Id': 112,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:49'},
#  {'Id': 112,
#   'Event': 'merge',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:49'},
#  {'Id': 112,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:49'},
#  {'Id': 112,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:49'},
#  {'Id': 112,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:49'},
#  {'Id': 112,
#   'Event': 'apply',
#   'Object': 'review',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:49'},
#  {'Id': 112,
#   'Event': 'patch',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:49'},
#  {'Id': 112,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:49'},
#  {'Id': 112,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:49'},
#  {'Id': 112,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:49'},
#  {'Id': 112,
#   'Event': 'make',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:49'},
#  {'Id': 112,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:49'},
#  {'Id': 112,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:49'},
#  {'Id': 112,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:49'},
#  {'Id': 112,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:49'},
#  {'Id': 113,
#   'Event': 'do',
#   'Object': 'undertowproducer',
#   'Actor': 'scott cranton',
#   'Timestamp': 'Wed, 05 Apr, 14:02'},
#  {'Id': 113,
#   'Event': 'see',
#   'Object': 'code',
#   'Actor': 'scott cranton',
#   'Timestamp': 'Wed, 05 Apr, 14:02'},
#  {'Id': 116,
#   'Event': 'work',
#   'Object': 'base',
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Fri, 07 Apr, 11:13'},
#  {'Id': 118,
#   'Event': 'affect',
#   'Object': 'version',
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Fri, 07 Apr, 11:27'},
#  {'Id': 119,
#   'Event': 'fix',
#   'Object': 'version',
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Fri, 07 Apr, 11:31'},
#  {'Id': 120,
#   'Event': 'work',
#   'Object': 'camelundertow',
#   'Actor': 'scott cranton',
#   'Timestamp': 'Fri, 07 Apr, 11:47'},
#  {'Id': 120,
#   'Event': 'create',
#   'Object': 'code',
#   'Actor': 'scott cranton',
#   'Timestamp': 'Fri, 07 Apr, 11:47'},
#  {'Id': 120,
#   'Event': 'use',
#   'Object': 'use',
#   'Actor': 'scott cranton',
#   'Timestamp': 'Fri, 07 Apr, 11:47'},
#  {'Id': 120,
#   'Event': 'get',
#   'Object': 'use',
#   'Actor': 'scott cranton',
#   'Timestamp': 'Fri, 07 Apr, 11:47'},
#  {'Id': 120,
#   'Event': 'use',
#   'Object': 'use',
#   'Actor': 'scott cranton',
#   'Timestamp': 'Fri, 07 Apr, 11:47'},
#  {'Id': 120,
#   'Event': 'think',
#   'Object': 'expectation',
#   'Actor': 'scott cranton',
#   'Timestamp': 'Fri, 07 Apr, 11:47'},
#  {'Id': 120,
#   'Event': 'get',
#   'Object': 'use',
#   'Actor': 'scott cranton',
#   'Timestamp': 'Fri, 07 Apr, 11:47'},
#  {'Id': 121,
#   'Event': 'need',
#   'Object': 'undertowhttpoperationfailureexception',
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Fri, 07 Apr, 13:35'},
#  {'Id': 123,
#   'Event': 'try',
#   'Object': 'try',
#   'Actor': 'scott cranton',
#   'Timestamp': 'Fri, 07 Apr, 13:45'},
#  {'Id': 123,
#   'Event': 'get',
#   'Object': 'try',
#   'Actor': 'scott cranton',
#   'Timestamp': 'Fri, 07 Apr, 13:45'},
#  {'Id': 124,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 10:18'},
#  {'Id': 124,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 10:18'},
#  {'Id': 125,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 22:43'},
#  {'Id': 125,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 22:43'},
#  {'Id': 125,
#   'Event': 'merge',
#   'Object': 'producer',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 22:43'},
#  {'Id': 125,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 22:43'},
#  {'Id': 125,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 22:43'},
#  {'Id': 125,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 22:43'},
#  {'Id': 125,
#   'Event': 'apply',
#   'Object': 'review',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 22:43'},
#  {'Id': 125,
#   'Event': 'patch',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 22:43'},
#  {'Id': 125,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 22:43'},
#  {'Id': 125,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 22:43'},
#  {'Id': 125,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 22:43'},
#  {'Id': 125,
#   'Event': 'make',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 22:43'},
#  {'Id': 125,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 22:43'},
#  {'Id': 125,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 22:43'},
#  {'Id': 125,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 22:43'},
#  {'Id': 125,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sat, 08 Apr, 22:43'},
#  {'Id': 126,
#   'Event': 'work',
#   'Object': 'work',
#   'Actor': 'scott cranton',
#   'Timestamp': 'Sat, 08 Apr, 22:47'},
#  {'Id': 128,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:23'},
#  {'Id': 128,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:23'},
#  {'Id': 129,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:27'},
#  {'Id': 129,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:27'},
#  {'Id': 129,
#   'Event': 'merge',
#   'Object': 'body',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:27'},
#  {'Id': 129,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:27'},
#  {'Id': 129,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:27'},
#  {'Id': 129,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:27'},
#  {'Id': 129,
#   'Event': 'apply',
#   'Object': 'review',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:27'},
#  {'Id': 129,
#   'Event': 'patch',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:27'},
#  {'Id': 129,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:27'},
#  {'Id': 129,
#   'Event': 'pull',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:27'},
#  {'Id': 129,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:27'},
#  {'Id': 129,
#   'Event': 'make',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:27'},
#  {'Id': 129,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:27'},
#  {'Id': 129,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:27'},
#  {'Id': 129,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:27'},
#  {'Id': 129,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 15:27'},
#  {'Id': 131,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 16:02'},
#  {'Id': 131,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Sun, 09 Apr, 16:02'},
#  {'Id': 134,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:39'},
#  {'Id': 134,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 05 Apr, 11:39'},
#  {'Id': 135,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': nan},
#  {'Id': 135,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': nan},
#  {'Id': 136,
#   'Event': 'fix',
#   'Object': 'fix',
#   'Actor': None,
#   'Timestamp': 'Wed, 05 Apr, 12:55'},
#  {'Id': 137, 'Event': 'fix', 'Object': 'fix', 'Actor': None, 'Timestamp': nan},
#  {'Id': 138,
#   'Event': 'fix',
#   'Object': 'fix',
#   'Actor': None,
#   'Timestamp': 'Wed, 05 Apr, 12:55'},
#  {'Id': 139, 'Event': 'fix', 'Object': 'fix', 'Actor': None, 'Timestamp': nan},
#  {'Id': 140,
#   'Event': 'fix',
#   'Object': 'camel10748',
#   'Actor': None,
#   'Timestamp': 'Wed, 05 Apr, 12:56'},
#  {'Id': 141,
#   'Event': 'fix',
#   'Object': 'camel10748',
#   'Actor': None,
#   'Timestamp': nan},
#  {'Id': 142,
#   'Event': 'fix',
#   'Object': 'fix',
#   'Actor': None,
#   'Timestamp': 'Wed, 05 Apr, 12:56'},
#  {'Id': 143, 'Event': 'fix', 'Object': 'fix', 'Actor': None, 'Timestamp': nan},
#  {'Id': 144,
#   'Event': 'fix',
#   'Object': 'camel10815',
#   'Actor': None,
#   'Timestamp': 'Wed, 05 Apr, 12:57'},
#  {'Id': 145,
#   'Event': 'fix',
#   'Object': 'camel10815',
#   'Actor': None,
#   'Timestamp': nan},
#  {'Id': 146,
#   'Event': 'fix',
#   'Object': 'fix',
#   'Actor': None,
#   'Timestamp': 'Wed, 05 Apr, 12:57'},
# ...
#  {'Id': 341,
#   'Event': 'fix',
#   'Object': 'cameljuel',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 05:02'},
#  {'Id': 341,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 05:02'},
#  {'Id': 341,
#   'Event': 'fix',
#   'Object': 'cameljuel',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 05:02'},
#  {'Id': 344,
#   'Event': 'pull',
#   'Object': 'tadayosi',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 08:11'},
#  {'Id': 344,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 08:11'},
#  {'Id': 345,
#   'Event': 'pull',
#   'Object': 'tadayosi',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'fail',
#   'Object': 'karaf',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'merge',
#   'Object': 'server',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'pull',
#   'Object': 'tadayosi',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'pull',
#   'Object': 'tadayosi',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'apply',
#   'Object': 'review',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'patch',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'pull',
#   'Object': 'tadayosi',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'make',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 345,
#   'Event': 'fail',
#   'Object': 'karaf',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:12'},
#  {'Id': 346,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:40'},
#  {'Id': 346,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 10:40'},
#  {'Id': 347,
#   'Event': 'affect',
#   'Object': 'component',
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Mon, 10 Apr, 12:49'},
#  {'Id': 347,
#   'Event': 'fix',
#   'Object': None,
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Mon, 10 Apr, 12:49'},
#  {'Id': 350,
#   'Event': 'provide',
#   'Object': 'summary',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:11'},
#  {'Id': 350,
#   'Event': 'fix',
#   'Object': None,
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:11'},
#  {'Id': 350,
#   'Event': 'provide',
#   'Object': 'summary',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:11'},
#  {'Id': 350,
#   'Event': 'provide',
#   'Object': 'summary',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:11'},
#  {'Id': 350,
#   'Event': 'see',
#   'Object': 'app',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:11'},
#  {'Id': 350,
#   'Event': 'allow',
#   'Object': 'route',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:11'},
#  {'Id': 350,
#   'Event': 'provide',
#   'Object': 'summary',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:11'},
#  {'Id': 350,
#   'Event': 'need',
#   'Object': 'annotation',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:11'},
#  {'Id': 350,
#   'Event': 'affect',
#   'Object': 'message',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:11'},
#  {'Id': 350,
#   'Event': 'need',
#   'Object': 'annotation',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:11'},
#  {'Id': 351,
#   'Event': 'provide',
#   'Object': 'step',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:14'},
#  {'Id': 351,
#   'Event': 'provide',
#   'Object': 'step',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:14'},
#  {'Id': 351,
#   'Event': 'see',
#   'Object': 'app',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:14'},
#  {'Id': 351,
#   'Event': 'allow',
#   'Object': 'route',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:14'},
#  {'Id': 351,
#   'Event': 'provide',
#   'Object': 'step',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:14'},
#  {'Id': 351,
#   'Event': 'need',
#   'Object': 'annotation',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:14'},
#  {'Id': 351,
#   'Event': 'affect',
#   'Object': 'message',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:14'},
#  {'Id': 351,
#   'Event': 'need',
#   'Object': 'annotation',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:14'},
#  {'Id': 351,
#   'Event': 'provide',
#   'Object': 'step',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:14'},
#  {'Id': 351,
#   'Event': 'provide',
#   'Object': 'step',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:14'},
#  {'Id': 351,
#   'Event': 'see',
#   'Object': 'app',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:14'},
#  {'Id': 351,
#   'Event': 'allow',
#   'Object': 'route',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:14'},
#  {'Id': 351,
#   'Event': 'provide',
#   'Object': 'step',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:14'},
#  {'Id': 351,
#   'Event': 'need',
#   'Object': 'annotation',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:14'},
#  {'Id': 351,
#   'Event': 'affect',
#   'Object': 'message',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:14'},
#  {'Id': 351,
#   'Event': 'need',
#   'Object': 'annotation',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': 'Mon, 10 Apr, 14:14'},
#  {'Id': 352,
#   'Event': 'provide',
#   'Object': 'step',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': nan},
#  {'Id': 352,
#   'Event': 'provide',
#   'Object': 'step',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': nan},
#  {'Id': 352,
#   'Event': 'see',
#   'Object': 'app',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': nan},
#  {'Id': 352,
#   'Event': 'allow',
#   'Object': 'route',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': nan},
#  {'Id': 352,
#   'Event': 'provide',
#   'Object': 'step',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': nan},
#  {'Id': 352,
#   'Event': 'need',
#   'Object': 'annotation',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': nan},
#  {'Id': 352,
#   'Event': 'affect',
#   'Object': 'message',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': nan},
#  {'Id': 352,
#   'Event': 'need',
#   'Object': 'annotation',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': nan},
#  {'Id': 352,
#   'Event': 'provide',
#   'Object': 'step',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': nan},
#  {'Id': 352,
#   'Event': 'provide',
#   'Object': 'step',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': nan},
#  {'Id': 352,
#   'Event': 'see',
#   'Object': 'app',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': nan},
#  {'Id': 352,
#   'Event': 'allow',
#   'Object': 'route',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': nan},
#  {'Id': 352,
#   'Event': 'provide',
#   'Object': 'step',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': nan},
#  {'Id': 352,
#   'Event': 'need',
#   'Object': 'annotation',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': nan},
#  {'Id': 352,
#   'Event': 'affect',
#   'Object': 'message',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': nan},
#  {'Id': 352,
#   'Event': 'need',
#   'Object': 'annotation',
#   'Actor': 'tomohisa igarashi',
#   'Timestamp': nan},
#  {'Id': 353,
#   'Event': 'start',
#   'Object': 'start',
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Tue, 11 Apr, 09:31'},
#  {'Id': 353,
#   'Event': 'fix',
#   'Object': 'fix',
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Tue, 11 Apr, 09:31'},
#  {'Id': 353,
#   'Event': 'do',
#   'Object': 'processor',
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Tue, 11 Apr, 09:31'},
#  {'Id': 353,
#   'Event': 'start',
#   'Object': 'start',
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Tue, 11 Apr, 09:31'},
#  {'Id': 353,
#   'Event': 'make',
#   'Object': 'service',
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Tue, 11 Apr, 09:31'},
#  {'Id': 358,
#   'Event': 'fix',
#   'Object': 'ferraro',
#   'Actor': 'atlassian jira',
#   'Timestamp': 'Tue, 11 Apr, 14:16'},
#  {'Id': 361,
#   'Event': 'affect',
#   'Object': 'feature',
#   'Actor': 'dmitry volodin',
#   'Timestamp': 'Tue, 11 Apr, 14:48'},
#  {'Id': 361,
#   'Event': 'fix',
#   'Object': 'dmitry',
#   'Actor': 'dmitry volodin',
#   'Timestamp': 'Tue, 11 Apr, 14:48'},
#  {'Id': 363,
#   'Event': 'pull',
#   'Object': 'dmvolod',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 363,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 363,
#   'Event': 'merge',
#   'Object': 'formatting',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 363,
#   'Event': 'pull',
#   'Object': 'dmvolod',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 363,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 363,
#   'Event': 'pull',
#   'Object': 'dmvolod',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 363,
#   'Event': 'apply',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 363,
#   'Event': 'patch',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 363,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 363,
#   'Event': 'pull',
#   'Object': 'dmvolod',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 363,
#   'Event': 'request',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 363,
#   'Event': 'make',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 363,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 363,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 363,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 363,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 363,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 15:03'},
#  {'Id': 364,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:05'},
#  {'Id': 364,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:05'},
#  {'Id': 365,
#   'Event': 'work',
#   'Object': 'work',
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Tue, 11 Apr, 18:06'},
#  {'Id': 365,
#   'Event': 'see',
#   'Object': 'work',
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Tue, 11 Apr, 18:06'},
#  {'Id': 366,
#   'Event': 'work',
#   'Object': 'work',
#   'Actor': 'claus ibsen',
#   'Timestamp': nan},
#  {'Id': 366,
#   'Event': 'see',
#   'Object': 'work',
#   'Actor': 'claus ibsen',
#   'Timestamp': nan},
#  {'Id': 367,
#   'Event': 'create',
#   'Object': 'summary',
#   'Actor': 'preben asmussen',
#   'Timestamp': 'Tue, 11 Apr, 18:09'},
#  {'Id': 367,
#   'Event': 'add',
#   'Object': 'release',
#   'Actor': 'preben asmussen',
#   'Timestamp': 'Tue, 11 Apr, 18:09'},
#  {'Id': 368,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'create',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'merge',
#   'Object': 'wrapping',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'apply',
#   'Object': 'review',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'patch',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'make',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 368,
#   'Event': 'commit',
#   'Object': 'request',
#   'Actor': 'asf github',
#   'Timestamp': 'Tue, 11 Apr, 18:29'},
#  {'Id': 369,
#   'Event': 'fix',
#   'Object': None,
#   'Actor': 'claus ibsen',
#   'Timestamp': 'Wed, 12 Apr, 19:25'},
#  {'Id': 370,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 12 Apr, 20:01'},
#  {'Id': 370,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Wed, 12 Apr, 20:01'},
#  {'Id': 371,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 15:21'},
#  {'Id': 371,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 15:21'},
#  {'Id': 371,
#   'Event': 'update',
#   'Object': 'camel11136',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 15:21'},
#  {'Id': 371,
#   'Event': 'merge',
#   'Object': 'bit',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 15:21'},
#  {'Id': 371,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 15:21'},
#  {'Id': 371,
#   'Event': 'request',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 15:21'},
#  {'Id': 371,
#   'Event': 'pull',
#   'Object': 'pull',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 15:21'},
#  {'Id': 371,
#   'Event': 'apply',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 15:21'},
#  {'Id': 371,
#   'Event': 'patch',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 15:21'},
#  {'Id': 371,
#   'Event': 'close',
#   'Object': 'change',
#   'Actor': 'asf github',
#   'Timestamp': 'Thu, 13 Apr, 15:21'},
#  ...]

# %% [markdown]
# # Create OCEL

# %%
import csv

ocel_columns = ['Id', 'Event', 'Object', 'Actor', 'Timestamp']

filename = 'ocel_file.csv'

with open(filename, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=ocel_columns)
    writer.writeheader()
    writer.writerows(ocel_entries)

# %%
# !pip install pm4py
# Out:
# Collecting pm4py
#   Downloading pm4py-2.7.5-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 39.5 MB/s eta 0:00:00
# Collecting deprecation (from pm4py)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from pm4py) (0.20.1)
# Collecting intervaltree (from pm4py)
#   Downloading intervaltree-3.1.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pm4py) (4.9.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pm4py) (3.7.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pm4py) (3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pm4py) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pm4py) (1.5.3)
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.10/dist-packages (from pm4py) (2.0.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from pm4py) (2022.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pm4py) (1.10.1)
# Collecting stringdist (from pm4py)
#   Downloading StringDist-1.0.9.tar.gz (7.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pm4py) (4.65.0)
# Requirement already satisfied: cvxopt in /usr/local/lib/python3.10/dist-packages (from pm4py) (1.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation->pm4py) (23.1)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from intervaltree->pm4py) (2.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pm4py) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pm4py) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pm4py) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pm4py) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pm4py) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pm4py) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pm4py) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->pm4py) (1.16.0)
# Building wheels for collected packages: intervaltree, stringdist
#   Building wheel for intervaltree (setup.py) ... done
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26099 sha256=70bcbcc6105eb7d2be89ee55020a893a5f7c16f550450d7c9df553ad2c9b2d0f
#   Stored in directory: /root/.cache/pip/wheels/fa/80/8c/43488a924a046b733b64de3fac99252674c892a4c3801c0a61
#   Building wheel for stringdist (setup.py) ... done
#   Created wheel for stringdist: filename=StringDist-1.0.9-cp310-cp310-linux_x86_64.whl size=24939 sha256=f1ebd5c990863254b5f0590db089bad2d2b2d42ee595ed6d4e288edeb3d97a10
#   Stored in directory: /root/.cache/pip/wheels/79/25/0a/4a0c2c7af31a8b473f6e10e30312396f31ae899722600d7b99
# Successfully built intervaltree stringdist
# Installing collected packages: stringdist, intervaltree, deprecation, pm4py
# Successfully installed deprecation-2.1.0 intervaltree-3.1.0 pm4py-2.7.5 stringdist-1.0.9

# %%
df = pd.DataFrame(ocel_entries)

# %%
df.head()
# Out:
#    Id    Event   Object             Actor           Timestamp
# 0   0   create   create  daniel fullarton  Sun, 02 Apr, 23:59
# 1   1     pull     pull        asf github  Mon, 03 Apr, 00:01
# 2   1  request     pull        asf github  Mon, 03 Apr, 00:01
# 3   1  resolve  request        asf github  Mon, 03 Apr, 00:01
# 4   1    merge     pull        asf github  Mon, 03 Apr, 00:01

# %%
import pm4py
dataframe = pm4py.format_dataframe(df, case_id='Id', activity_key='Event', timestamp_key='Timestamp')
log = pm4py.convert_to_event_log(dataframe)
ocel_str = pm4py.convert_log_to_ocel(log)
log = pm4py.write_ocel_csv(ocel_str,"/content/ocel_events.csv","/content/ocel_objects.csv")
# Out:
# <ipython-input-122-d8b3c20a5390>:2: DeprecatedWarning: format_dataframe is deprecated as of 2.3.0 and will be removed in 3.0.0. the format_dataframe function does not need application anymore.
#   dataframe = pm4py.format_dataframe(df, case_id='Id', activity_key='Event', timestamp_key='Timestamp')
# /usr/local/lib/python3.10/dist-packages/pm4py/utils.py:93: UserWarning: Some rows of the Pandas data frame have been removed because of empty case IDs, activity labels, or timestamps to ensure the correct functioning of PM4Py's algorithms.
#   warnings.warn("Some rows of the Pandas data frame have been removed because of empty case IDs, activity labels, or timestamps to ensure the correct functioning of PM4Py's algorithms.")
# /usr/local/lib/python3.10/dist-packages/pm4py/utils.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[constants.CASE_CONCEPT_NAME] = df[constants.CASE_CONCEPT_NAME].astype("string")
# /usr/local/lib/python3.10/dist-packages/pm4py/utils.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[xes_constants.DEFAULT_NAME_KEY] = df[xes_constants.DEFAULT_NAME_KEY].astype("string")
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-122-d8b3c20a5390> in <cell line: 3>()
#       1 import pm4py
#       2 dataframe = pm4py.format_dataframe(df, case_id='Id', activity_key='Event', timestamp_key='Timestamp')
# ----> 3 log = pm4py.convert_to_event_log(dataframe)
#       4 ocel_str = pm4py.convert_log_to_ocel(log)
#       5 log = pm4py.write_ocel_csv(ocel_str,"/content/ocel_events.csv","/content/ocel_objects.csv")
#
# /usr/local/lib/python3.10/dist-packages/pm4py/convert.py in convert_to_event_log(obj, case_id_key, **kwargs)
#      57
#      58     if check_is_pandas_dataframe(obj):
# ---> 59         check_pandas_dataframe_columns(obj, case_id_key=case_id_key)
#      60
#      61     parameters = get_properties(obj, case_id_key=case_id_key)
#
# /usr/local/lib/python3.10/dist-packages/pm4py/util/pandas_utils.py in check_pandas_dataframe_columns(df, activity_key, case_id_key, timestamp_key)
#     283
#     284     if len(timest_columns) < 1:
# --> 285         raise Exception("the dataframe should (at least) contain a column of type date")
#     286
#     287     if case_id_key is not None:
#
# Exception: the dataframe should (at least) contain a column of type date
